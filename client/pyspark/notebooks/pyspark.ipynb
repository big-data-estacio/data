# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
import pyspark.sql.types as T

# %%
# cria uma nova sessão Spark
spark = SparkSession.builder.appName("myApp").getOrCreate()

# %%
df_bebidas = spark.read.format("csv") \
    .option("header", True) \
    .option("delimiter", ",") \
    .option("inferSchema", True) \
    .load("dbfs:/FileStore/shared_uploads/estevamsouzalaureth@gmail.com/bebidas-3.csv")

# %%
df_bebidas.show(10)
# Out:
# +---+---------------+-----+----------+------------+-----------+-----------------+
# | ID|           NOME|PRECO|QUANTIDADE|   DESCRICAO|TOTAL_ENDAS|QUANTIDADE_VENDAS|
# +---+---------------+-----+----------+------------+-----------+-----------------+
# |  1|      Coca-Cola|  4.5|        10|Refrigerante|        0.0|                0|
# |  2|        Guaraná|  3.5|        10|Refrigerante|        0.0|                0|
# |  3|Suco de Laranja|  5.0|        10|        Suco|        0.0|                0|
# |  4|    Suco de Uva|  5.0|        10|        Suco|        0.0|                0|
# |  5|           Água|  2.0|        10|        Água|        0.0|                0|
# +---+---------------+-----+----------+------------+-----------+-----------------+

# %%
# Para gerar os gráficos:
import pandas as pd
import matplotlib.pyplot as plt

df_bebidas_pd = df_bebidas.select("nome", "preco").toPandas()
df_bebidas_pd.hist(column="preco", bins=20)
plt.show()
